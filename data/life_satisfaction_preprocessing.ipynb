# %%
import pandas as pd

# %%
# 2022년 자료
filename = 'life_satisfaction_original.csv'
satisDF = pd.read_csv(filename, skiprows=1)
satisDF
# Out:
#   대상별(1) 특성별(1)                특성별(2)  합계 (%)  매우 만족 (%)  약간 만족 (%)  보통 (%)  \
# 0    외국인  체류자격별                     계   100.0       40.8       39.6    17.7
# 1    외국인  체류자격별            비전문취업(E-9)   100.0       47.4       37.3    14.4
# 2    외국인  체류자격별             방문취업(H-2)   100.0       35.8       40.2    21.5
# 3    외국인  체류자격별         전문인력(E-1~E-7)   100.0       42.2       41.2    13.9
# 4    외국인  체류자격별  유학생(D-2 D-4-1 D-4-7)   100.0       38.8       41.1    18.3
# 5    외국인  체류자격별             재외동포(F-4)   100.0       38.2       41.3    18.6
# 6    외국인  체류자격별               영주(F-5)   100.0       40.4       39.3    18.4
# 7    외국인  체류자격별       결혼이민(F-2-1 F-6)   100.0       43.6       38.7    15.9
# 8    외국인  체류자격별                    기타   100.0       41.5       37.2    18.7
#
#    약간 불만족 (%)  매우 불만족 (%)
# 0         1.7         0.2
# 1         0.9         0.0
# 2         2.3         0.3
# 3         1.9         0.5
# 4         1.5         0.4
# 5         1.7         0.2
# ...

# %%
satisDF.columns = ['대상별', '특성별1', '특성별2', '합계', '매우만족', '약간만족', '보통', '약간불만족', '매우불만족']
satisDF
# Out:
#    대상별   특성별1                  특성별2     합계  매우만족  약간만족    보통  약간불만족  매우불만족
# 0  외국인  체류자격별                     계  100.0  40.8  39.6  17.7    1.7    0.2
# 1  외국인  체류자격별            비전문취업(E-9)  100.0  47.4  37.3  14.4    0.9    0.0
# 2  외국인  체류자격별             방문취업(H-2)  100.0  35.8  40.2  21.5    2.3    0.3
# 3  외국인  체류자격별         전문인력(E-1~E-7)  100.0  42.2  41.2  13.9    1.9    0.5
# 4  외국인  체류자격별  유학생(D-2 D-4-1 D-4-7)  100.0  38.8  41.1  18.3    1.5    0.4
# 5  외국인  체류자격별             재외동포(F-4)  100.0  38.2  41.3  18.6    1.7    0.2
# 6  외국인  체류자격별               영주(F-5)  100.0  40.4  39.3  18.4    1.7    0.1
# 7  외국인  체류자격별       결혼이민(F-2-1 F-6)  100.0  43.6  38.7  15.9    1.5    0.2
# 8  외국인  체류자격별                    기타  100.0  41.5  37.2  18.7    2.3    0.4

# %%
# 전처리 끝난 DF 파일로 저장
satisDF.to_csv('life_satisfaction.csv', index=False)

# %%
# 2022년 자료
filename = 'society_member_original.csv'
memDF = pd.read_csv(filename, skiprows=1)
memDF
# Out:
#   특성별(1)         특성별(2)  합계 (%)  전혀 문제가 되지 않음 (%)  별로 문제가 되지 않음 (%)  \
# 0  체류자격별              계   100.0              22.6              44.9
# 1  체류자격별  영주(F-5 F-5-2)   100.0              23.0              45.3
# 2  체류자격별          귀화허가자   100.0              21.6              43.9
#
#    약간 문제가 됨 (%)  매우 문제가 됨 (%)  모르겠음 (%)
# 0          25.1           4.1       3.4
# 1          24.0           4.2       3.5
# 2          27.8           3.6       3.1

# %%
memDF.columns = ['특성별1', '특성별2', '합계', '전혀문제가되지않음', '별로문제가되지않음', '약간문제가됨', '매우문제가됨', '모르겠음']
memDF
# Out:
#     특성별1           특성별2     합계  전혀문제가되지않음  별로문제가되지않음  약간문제가됨  매우문제가됨  모르겠음
# 0  체류자격별              계  100.0       22.6       44.9    25.1     4.1   3.4
# 1  체류자격별  영주(F-5 F-5-2)  100.0       23.0       45.3    24.0     4.2   3.5
# 2  체류자격별          귀화허가자  100.0       21.6       43.9    27.8     3.6   3.1

# %%
# 전처리 끝난 DF 파일로 저장
memDF.to_csv('society_member.csv', index=False)
